# %%
import pandas as pd

# %%
#!python -m pip install requests

#conda install -c anaconda requests

# %%
import requests # request img from web
#import shutil # save img locally

# %%
iNat_images = pd.read_csv('Data/iNat_train_val_image_DL_list.csv', sep=",")



iNat_images['image_url']=iNat_images['image_url'].str.replace('medium', 'small')

# %%
# need to manually create an Images folder in working directory if not already present

for ind in iNat_images.index:
    response = requests.get(iNat_images['image_url'][ind])
    
    if response.status_code:
        fp = open('Images/'+str(iNat_images['id'][ind])+'.jpg', 'wb')
        fp.write(response.content)
        fp.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Admin\OneDrive - UNSW\Course work\_CV4E\Python Code\Clean_code\kelp_CV\kelp_classifier\_1_iNat_train_image_download.ipynb Cell 5 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/OneDrive%20-%20UNSW/Course%20work/_CV4E/Python%20Code/Clean_code/kelp_CV/kelp_classifier/_1_iNat_train_image_download.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> # need to manually create an Images folder in working directory if not already present
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/OneDrive%20-%20UNSW/Course%20work/_CV4E/Python%20Code/Clean_code/kelp_CV/kelp_classifier/_1_iNat_train_image_download.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> for ind in iNat_images.index:
# ...
